# %%
import pandas as pd
from pathlib import Path

# auto reload magic
# %load_ext autoreload
# %autoreload 2
from agentlab.analyze import hparam_analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_path = Path("~").expanduser() / "bootstrap_analysis_data_0.csv"
df = pd.read_csv(csv_path)

df["base_exp_args_base_model_dir"] = df["base_exp_args_base_model_dir"].str.replace(
    "/mnt/adea/data/finetuning/base/", "", regex=False
)

# %%
metric_col = "avg_completion_reward"
hp_cols = list(df.columns)
hp_cols.remove("base_exp_args_wandb_job_id")
hp_cols.remove(metric_col)
hp_cols
# Out:
# ['process_traces_args_pop_zero_advantage',
#  'evaluation_args_use_curriculum',
#  'base_exp_args_training_sampling_temperature',
#  'process_traces_args_discount_rate',
#  'base_exp_args_base_model_dir',
#  'evaluation_args_agent_flags_obs_use_error_logs',
#  'process_traces_args_apply_advantage',
#  'finetuning_args_effective_batch_size',
#  'epoch']

# %%
for focus_col in hp_cols:
    print(f"Focus column: {focus_col}")
    df_result = hparam_analysis.bootstrap_optimal_hparam(
        df,
        hp_cols,
        focus_col=focus_col,
        metric_col=metric_col,
        n_boot=1000,
    )
    display(df_result)
# Out:
# Focus column: process_traces_args_pop_zero_advantage
#          prob
# values
# False   0.484
# True    0.516
# Focus column: evaluation_args_use_curriculum
#          prob
# values
# False   0.891
# True    0.109
# Focus column: base_exp_args_training_sampling_temperature
#          prob
# values
# 0.1     0.407
# 0.25    0.127
# 0.5     0.435
# 0.75    0.029
# 1.0     0.002
# Focus column: process_traces_args_discount_rate
#          prob
# values
# 0.5     0.000
# 0.8     0.000
# 0.9     0.003
# 0.95    0.000
# 0.98    0.721
# 1.0     0.276
# Focus column: base_exp_args_base_model_dir
#                                                      prob
# values
# 20250427_022653_offline_miniwob_random_tasks_v5...  0.000
# 20250427_022653_offline_miniwob_random_tasks_v5...  0.000
# 20250427_022653_offline_miniwob_random_tasks_v5...  0.020
# 20250427_022653_offline_miniwob_random_tasks_v5...  0.000
# 20250427_022653_offline_miniwob_random_tasks_v5...  0.000
# ...

# %%
hparam_analysis.pedanova_importance(df, hp_cols, metric_col=metric_col)

# %%
hparam_analysis.fanova_mc(df, hp_cols, metric_col=metric_col)

# %%
hparam_analysis.fanova_df_(df, hp_cols, metric_col=metric_col)
